# %% [markdown]
# ## 시각화 패키지 Matplotlib

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
# %matplotlib inline

# %%
# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
fm._rebuild()
sorted([f.name for f in fm.fontManager.ttflist if f.name.startswith("Nanum")])
# Out:
# ['Nanum Brush Script',
#  'Nanum Pen Script',
#  'NanumBarunGothic',
#  'NanumBarunGothic',
#  'NanumBarunGothic',
#  'NanumBarunGothic',
#  'NanumBarunGothic YetHangul',
#  'NanumBarunpen',
#  'NanumBarunpen',
#  'NanumGothic',
#  'NanumGothic',
#  'NanumGothic',
#  'NanumGothic',
#  'NanumGothic Eco',
#  'NanumGothicCoding',
#  'NanumGothicCoding',
#  'NanumMyeongjo',
#  'NanumMyeongjo',
#  'NanumMyeongjo',
#  'NanumMyeongjo Eco',
#  'NanumMyeongjo YetHangul',
#  'NanumSquare',
#  'NanumSquare',
#  'NanumSquare',
#  'NanumSquare',
#  'NanumSquareRound',
#  'NanumSquareRound',
#  'NanumSquareRound',
#  'NanumSquareRound',
#  'NanumSquare_ac',
#  'NanumSquare_ac',
#  'NanumSquare_ac',
#  'NanumSquare_ac']

# %%
[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Malgun' in f.name]
# Out:
# [('Malgun Gothic', 'C:\\windows\\Fonts\\malgunsl.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgun.ttf'),
#  ('Malgun Gothic', 'C:\\windows\\Fonts\\malgunbd.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunbd.ttf'),
#  ('Malgun Gothic', 'C:\\windows\\Fonts\\malgun.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunsl.ttf')]

# %%
[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [('NanumBarunGothic',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBarunGothicLight.ttf'),
#  ('NanumBarunpen',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBarunpenB.ttf'),
#  ('NanumMyeongjo',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumMyeongjo.ttf'),
#  ('NanumGothic',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothicBold.ttf'),
#  ('NanumSquare_ac',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquare.ttf'),
#  ('NanumSquare_ac',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquare_acL.ttf'),
#  ('Nanum Pen Script',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumPen.ttf'),
#  ('NanumBarunGothic',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBarunGothic.ttf'),
#  ('NanumSquareRound',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareRoundL.ttf'),
#  ('NanumSquare',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareEB.ttf'),
#  ('NanumBarunGothic',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBarunGothicUltraLight.ttf'),
#  ('NanumMyeongjo Eco',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumMyeongjoEcoR.ttf'),
#  ('NanumBarunGothic YetHangul',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBarunGothic-YetHangul.ttf'),
#  ('NanumSquare',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareB.ttf'),
#  ('NanumMyeongjo YetHangul',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumMyeongjo-YetHangul.ttf'),
#  ('NanumSquareRound',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareRoundEB.ttf'),
#  ('NanumSquare',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareR.ttf'),
#  ('NanumGothic Eco',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothicEcoR.ttf'),
#  ('NanumGothic',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothicLight.ttf'),
#  ('NanumBarunGothic',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBarunGothicBold.ttf'),
#  ('Nanum Brush Script',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBrush.ttf'),
#  ('NanumSquare_ac',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquare_acR.ttf'),
#  ('NanumGothicCoding',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothicCoding.ttf'),
#  ('NanumGothicCoding',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothicCodingBold.ttf'),
#  ('NanumMyeongjo',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumMyeongjoExtraBold.ttf'),
#  ('NanumSquareRound',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareRoundR.ttf'),
#  ('NanumSquareRound',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareRoundB.ttf'),
#  ('NanumSquare',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareL.ttf'),
#  ('NanumGothic',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothicExtraBold.ttf'),
#  ('NanumGothic',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothic.ttf'),
#  ('NanumBarunpen',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBarunpenR.ttf'),
#  ('NanumSquare_ac',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquare_0.ttf'),
#  ('NanumMyeongjo',
#   'C:\\Users\\kimee\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumMyeongjoBold.ttf')]

# %%
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 10

# %%
# %matplotlib inline

# %%
import math
xs, ysin, ycos = [], [], []
for x in range(360):
    xs.append(x)
    ysin.append(np.sin(math.pi * x / 180))
    ycos.append(np.cos(math.pi * x / 180))

xs = np.arange(-6, 2*np.pi, 0.01)
ysin = np.sin(xs); ycos = np.cos(xs)
plt.plot(xs, ysin, label='Sine curve')
plt.plot(xs, ycos, label='Cosine curve')
plt.xlim([-6, 2*np.pi+0.1]); plt.ylim([-1.2, 1.2])
plt.xlabel('X-Value'); plt.ylabel('Y-Value')
plt.title('삼각함수')
plt.legend(loc='center') # label을 범례로 표시
plt.axhline(y=0, color='k', linewidth=0.5) # 수평선(x축)
plt.axvline(x=0, color='k', linewidth=0.5) # 수직선(y축)
plt.axvline(x=360, color='k', linewidth=0.5)
plt.show()
